# %%
import pandas as pd

# %%
df = pd.read_pickle("20221211_python")
df.head()
# Out:
#                                         id  \
# id
# 5244989e5b5aad733e6c  5244989e5b5aad733e6c
# e3b68c3b15ca7536f863  e3b68c3b15ca7536f863
# bfccba5f4e57f8cb4b3a  bfccba5f4e57f8cb4b3a
# b27578bb601742dad7e6  b27578bb601742dad7e6
# 4da08f935788a29e9ff6  4da08f935788a29e9ff6
#
#                                                                    body  \
# id
# 5244989e5b5aad733e6c  少しblenderで遊んで見ようかと\n最終的な目的は、blender-pythonでアニメ...
# e3b68c3b15ca7536f863  初投稿。\n先月はじめてラズパイを購入してみました。\n元々ネットワーク勉強用として使ってい...
# bfccba5f4e57f8cb4b3a  # 1. 前書き\nAtCoderBeginnerContest(ABC)の参加結果と内容の...
# b27578bb601742dad7e6  # はじめに\n今更な内容ではあるが、タイトルの通り。\npathlib も同じようなことが...
# 4da08f935788a29e9ff6  # よく使う\n## エラーハンドリング\n### traceback\n```python...
#
#                                                                    tags  \
# id
# 5244989e5b5aad733e6c  [{'name': 'Python', 'versions': []}, {'name': ...
# e3b68c3b15ca7536f863  [{'name': 'Python', 'versions': []}, {'name': ...
# ...
